# %%
import requests
web = requests.get('https://scrapepark.org/')
print(web)
# Out:
# <Response [200]>

# %%
web.content
# Out:
# b'<!DOCTYPE html>\r\n<html>\r\n\r\n  <head>\r\n    <!-- Basic -->\r\n    <meta charset="utf-8">\r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <!-- Mobile Metas -->\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">\r\n    <!-- Site Metas -->\r\n    <meta name="keywords" content>\r\n    <meta name="description" content>\r\n    <meta name="author" content>\r\n    <link rel="shortcut icon" href="images/favicon.svg" type>\r\n    <title>ScrapePark.org</title>\r\n    <!-- bootstrap core css -->\r\n    <link rel="stylesheet" type="text/css" href="css/bootstrap.css">\r\n    <!-- font awesome style -->\r\n    <link href="css/font-awesome.min.css" rel="stylesheet">\r\n    <!-- Custom styles for this template -->\r\n    <link href="css/style.css" rel="stylesheet">\r\n    <!-- responsive style -->\r\n    <link href="css/responsive.css" rel="stylesheet">\r\n  </head>\r\n\r\n  <body>\r\n    <div class="hero-area">\r\n      <!-- heade
# ...

# %%
web.url
# Out:
# 'https://scrapepark.org/'

# %%
web.status_code
# Out:
# 200

# %% [markdown]
# HTML Parsing in web page using python

# %%
import requests
from bs4 import BeautifulSoup
web = requests.get('https://scrapepark.org/')
soup = BeautifulSoup(web.content, 'html.parser')
soup.prettify()
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <!-- Basic -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <!-- Mobile Metas -->
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <!-- Site Metas -->
#   <meta content="" name="keywords"/>
#   <meta content="" name="description"/>
#   <meta content="" name="author"/>
#   <link href="images/favicon.svg" rel="shortcut icon" type=""/>
#   <title>
#    ScrapePark.org
#   </title>
#   <!-- bootstrap core css -->
#   <link href="css/bootstrap.css" rel="stylesheet" type="text/css"/>
#   <!-- font awesome style -->
#   <link href="css/font-awesome.min.css" rel="stylesheet"/>
#   <!-- Custom styles for this template -->
#   <link href="css/style.css" rel="stylesheet"/>
#   <!-- responsive style -->
#   <link href="css/responsive.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <div class="hero-area">
#    <!-- header section strats -->
# ...

# %%
soup.title
# Out:
# <title>ScrapePark.org</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.p
# Out:
# <p>Find our awesome sales.</p>

# %%
soup.a
# Out:
# <a class="navbar-brand" href="/">
# <img alt="ScrapePark.org Logo" src="images/logo.svg" width="250"/>
# </a>

# %%
soup.h1
# Out:
# <h1>
# <span>
# <span>Discounts</span><br/>20% Off
#                         </span>
# <br/>
# <span id="all-products">On all our products!</span>
# </h1>

# %% [markdown]
# Kinds of Objects in Beautiful Soup -:
# 1. Tag -: Like h1 tag, img tag, p tag ... etc.
# 2. NavigableString -: Tag ke ander jo likha hota hai wo khelata hai NavigableString
# 3. BeautifulSoup -: It give info of header tag used in website.
# 4. Comments -: It give info of all comments used in website.

# %%
import requests
from bs4 import BeautifulSoup
web = requests.get('https://scrapepark.org/')
soup = BeautifulSoup(web.content, 'html.parser')

# %% [markdown]
# # Tag

# %%
tag = soup.html

# %%
type(tag)
# Out:
# bs4.element.Tag

# %%
tag = soup.p
tag
# Out:
# <p>Find our awesome sales.</p>

# %%
tag = soup.a 
tag
# Out:
# <a class="navbar-brand" href="/">
# <img alt="ScrapePark.org Logo" src="images/logo.svg" width="250"/>
# </a>

# %%
tag = soup.h1
tag
# Out:
# <h1>
# <span>
# <span>Discounts</span><br/>20% Off
#                         </span>
# <br/>
# <span id="all-products">On all our products!</span>
# </h1>

# %%
tag = soup.h2
tag
# Out:
# <h2>Why choose our skateboards?</h2>

# %% [markdown]
# # NavigableString

# %%
tag = soup.h2.string
tag
# Out:
# 'Why choose our skateboards?'

# %%
tag = soup.p.string
tag
# Out:
# 'Find our awesome sales.'

# %% [markdown]
# # BeautifulSoup

# %%
soup.title
# Out:
# <title>ScrapePark.org</title>

# %%
soup.head
# Out:
# <head>
# <!-- Basic -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!-- Mobile Metas -->
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <!-- Site Metas -->
# <meta content="" name="keywords"/>
# <meta content="" name="description"/>
# <meta content="" name="author"/>
# <link href="images/favicon.svg" rel="shortcut icon" type=""/>
# <title>ScrapePark.org</title>
# <!-- bootstrap core css -->
# <link href="css/bootstrap.css" rel="stylesheet" type="text/css"/>
# <!-- font awesome style -->
# <link href="css/font-awesome.min.css" rel="stylesheet"/>
# <!-- Custom styles for this template -->
# <link href="css/style.css" rel="stylesheet"/>
# <!-- responsive style -->
# <link href="css/responsive.css" rel="stylesheet"/>
# </head>

# %%
soup.body
# Out:
# <body>
# <div class="hero-area">
# <!-- header section strats -->
# <header class="header-section">
# <div class="container">
# <nav class="navbar navbar-expand-lg custom-nav-container">
# <a class="navbar-brand" href="/">
# <img alt="ScrapePark.org Logo" src="images/logo.svg" width="250"/>
# </a>
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <span class=""> </span>
# </button>
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav">
# <li class="nav-item active">
# <a class="nav-link" href="/">Home</a>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="true" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" role="button">
# <span class="nav-label">Content</span>
# </a>
# <ul class="dropdown-menu">
# <li><a href="#about">About</a></li>
# ...

# %%
# find function give only first things that come, which we asked in ()
soup.find("h1")
# Out:
# <h1>
# <span>
# <span>Discounts</span><br/>20% Off
#                         </span>
# <br/>
# <span id="all-products">On all our products!</span>
# </h1>

# %%
# find_all fuction give all what we have put in ()
soup.find_all("h1")
# Out:
# [<h1>
#  <span>
#  <span>Discounts</span><br/>20% Off
#                          </span>
#  <br/>
#  <span id="all-products">On all our products!</span>
#  </h1>,
#  <h1>
#  <span>
#  <span>Discounts</span><br/>20% Off
#                          </span>
#  <br/>
#  <span id="all-products">On all our products!</span>
#  </h1>,
#  <h1>
#  <span>
#  <span>Discounts</span><br/>20% Off
#                          </span>
#  <br/>
#  <span id="all-products">On all our products!</span>
#  </h1>]

# %%
# give only first paragraph
soup.find("p")
# Out:
# <p>Find our awesome sales.</p>

# %%
# give all paragraph
soup.find_all("p")
# Out:
# [<p>Find our awesome sales.</p>,
#  <p>Find our awesome sales.</p>,
#  <p>Find our awesome sales.</p>,
#  <p style="margin-top: 20px;margin-bottom: 30px;">Don't miss our latest products!</p>,
#  <p class="customer-comment">I love the products and the prices are awesome. I recommend this store.</p>,
#  <p class="customer-comment">The quality and variety of skateboards are amazing! I will definitely buy here again.</p>,
#  <p class="customer-comment">I'm very happy with my purchase. This store has many skateboards and the designs are great.</p>,
#  <p><strong>ADDRESS</strong>: <span>Fake Street 123</span></p>,
#  <p><strong>PHONE</strong>: 4-444-4444</p>,
#  <p><strong>EMAIL</strong>: <span>sales@mail.com</span> </p>,
#  <p>© 2022 <span>All Rights Reserved</span>.
#          <a href="https://html.design/" rel="noopener noreferrer" target="_blank">Created with Free Html Templates</a>.
#        </p>]

# %% [markdown]
# # Comments

# %%
com = soup.p.string
com
# Out:
# 'Find our awesome sales.'

# %%
soup.p.prettify() # prettify arrange the code in readable and beautiful format
# Out:
# '<p>\n Find our awesome sales.\n</p>\n'

# %%
print(soup.body.prettify())
# Out:
# <body>
#  <div class="hero-area">
#   <!-- header section strats -->
#   <header class="header-section">
#    <div class="container">
#     <nav class="navbar navbar-expand-lg custom-nav-container">
#      <a class="navbar-brand" href="/">
#       <img alt="ScrapePark.org Logo" src="images/logo.svg" width="250"/>
#      </a>
#      <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
#       <span class="">
#       </span>
#      </button>
#      <div class="collapse navbar-collapse" id="navbarSupportedContent">
#       <ul class="navbar-nav">
#        <li class="nav-item active">
#         <a class="nav-link" href="/">
#          Home
#         </a>
#        </li>
#        <li class="nav-item dropdown">
#         <a aria-expanded="true" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" role="button">
# ...
